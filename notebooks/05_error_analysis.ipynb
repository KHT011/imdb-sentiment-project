# %% [markdown]
# # IMDB Reviews - Error Analysis

# %%
from pathlib import Path
import pandas as pd

# %%
# Load misclassified examples
data_path = Path("../reports/metrics/svm_tfidf_misclassified.csv")
df = pd.read_csv(data_path)
df.head(3)
# Out:
#                                                 text      true      pred
# 0  yes mtv really way market daria started clever...  negative  positive
# 1  little quentin mastered art having cake eating...  negative  positive
# 2  film listed having num the_NEG film_NEG which_...  negative  positive

# %%
def print_row(idx):
    print(f"Review: {idx +1}")
    print(df.iloc[idx]['text'])
    print(f"Actual: {df.iloc[idx]['true']}")
    print(f"Predicted: {df.iloc[idx]['pred']}")

# %%
print_row(0)
# Out:
# Review: 1
# yes mtv really way market daria started clever teenage angst- comment suck make viewer feel better sucky teenage life sitcom mutated deal problem -charade used watch daria time loved sitting watching called movie wonder point daria tell lead life college excuse did the_NEG point_NEG daria_NEG made_NEG every_NEG episode_NEG that_NEG what_NEG you_NEG like_NEG to_NEG do_NEG is_NEG ok_NEG long ok matter_NEG what_NEG the_NEG rest_NEG of_NEG the_NEG sick_NEG sad_NEG world_NEG think_NEG of_NEG it_NEG entire thing reminded scene reality bite movie channel show documentry time
# Actual: negative
# Predicted: positive

# %%
print_row(1)
# Out:
# Review: 2
# little quentin mastered art having cake eating usual pure sadistic display explained clever thought-provoking way sending violence audience face sure mr tarantino violence baaad sadism baaad worth wading make point brilliant juvenile audience be_NEG clever_NEG enough_NEG to_NEG follow_NEG all_NEG the_NEG smart_NEG reference_NEG to_NEG higher_NEG level_NEG of_NEG consciousness_NEG though_NEG confident light day thanks making little world little better deserve medal
# Actual: negative
# Predicted: positive

# %%
print_row(2)
# Out:
# Review: 3
# film listed having num the_NEG film_NEG which_NEG is_NEG available_NEG from_NEG something_NEG weird_NEG video_NEG in_NEG their_NEG ``_NEG driver_NEG 's_NEG ed_NEG scare_NEG film_NEG vol_NEG num thing num version color swv disc earlier version num film b w wlwt television channel num cincinnati way film notorious unlike driver ed film intended television broadcast viewing general public level carnage ratcheted pretty grim exercise exploitation bloody death purported educational intent live cincinnati area remember thing shown year prom time channel num looking film demonstrates tone uniquely american film phenomenon prom pretty typical - morose hyperbolic extremely didactic heavy melodrama really affected teenager driving guess
# Actual: negative
# Predicted: positive
